# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
evap = pd.read_csv(r'C:\Users\Dell\Downloads\EVAPA2.csv')

# %%
evap.head()
# Out:
#                Time FIC3001A.PV | Value FIC3011A.PV | Value  \
# 0       Description         EVAP A FEED       LPS TO EVAP A
# 1             Units               M3/hr               M3/HR
# 2  01-04-2022 00:00                0.01               -0.07
# 3  01-04-2022 00:15                0.01               -0.07
# 4  01-04-2022 00:30                0.01               -0.07
#
#   PIC3031A.PV | Value PIC3001A.PV | Value TI3001A.PV | Value  \
# 0       LPS TO EVAP A   EVAP A FLASH CHMB  EVAP A FLASH CHMB
# 1              KG/CM2              Kg/cm2              Deg C
# 2                0.05                4.69              29.13
# 3                0.05                4.71               29.1
# 4                0.05                4.74              29.13
#
#      TI3011A.PV | Value      FI3021A.PV | Value    GA3001A-AI.PV | Value
# 0  EVAP A HEAT BODY O/L  PROCESS WTR TO GB3001A  EVAP CIRC PMP A CURRENT
# 1                 Deg C                   M3/HR                     Amps
# ...

# %%
evap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25635 entries, 0 to 25634
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Time                   25635 non-null  object
#  1   FIC3001A.PV | Value    25635 non-null  object
#  2   FIC3011A.PV | Value    25635 non-null  object
#  3   PIC3031A.PV | Value    25635 non-null  object
#  4   PIC3001A.PV | Value    25635 non-null  object
#  5   TI3001A.PV | Value     25635 non-null  object
#  6   TI3011A.PV | Value     25635 non-null  object
#  7   FI3021A.PV | Value     25344 non-null  object
#  8   GA3001A-AI.PV | Value  25374 non-null  object
# dtypes: object(9)
# memory usage: 1.8+ MB

# %%
evap.describe()
# Out:
#                     Time FIC3001A.PV | Value FIC3011A.PV | Value  \
# count              25635               25635               25635
# unique             25443                2272                 847
# top     30-04-2022 21:30                0.01               -0.07
# freq                   2                1455                1234
#
#        PIC3031A.PV | Value PIC3001A.PV | Value TI3001A.PV | Value  \
# count                25635               25635              25635
# unique                 109                8444               4041
# top                    0.9                5.12              72.49
# freq                  6387                  67                 38
#
#        TI3011A.PV | Value FI3021A.PV | Value GA3001A-AI.PV | Value
# count               25635              25344                 25374
# unique               4072                893                  4878
# top                 76.36               5.94                102.14
# ...

# %%
evap.shape
# Out:
# (25635, 9)

# %%
evap.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
evap.isnull().sum()
# Out:
# Time                       0
# FIC3001A.PV | Value        0
# FIC3011A.PV | Value        0
# PIC3031A.PV | Value        0
# PIC3001A.PV | Value        0
# TI3001A.PV | Value         0
# TI3011A.PV | Value         0
# FI3021A.PV | Value       291
# GA3001A-AI.PV | Value    261
# dtype: int64

# %%
evap1=evap.dropna()

# %%
evap1.head(5)
# Out:
#                  Time FIC3001A.PV | Value FIC3011A.PV | Value  \
# 293  04-04-2022 00:45               21.25               -0.07
# 294  04-04-2022 01:00               18.27               -0.07
# 295  04-04-2022 01:15               12.47               -0.07
# 296  04-04-2022 01:30                0.02               -0.04
# 297  04-04-2022 01:45               -0.01               -0.05
#
#     PIC3031A.PV | Value PIC3001A.PV | Value TI3001A.PV | Value  \
# 293                0.05              -82.17               52.8
# 294                0.05              -80.22              55.93
# 295                0.05             -104.02              54.39
# 296                0.05              -88.24              55.31
# 297                0.05              -81.89              54.81
#
#     TI3011A.PV | Value FI3021A.PV | Value GA3001A-AI.PV | Value
# 293              59.11               5.02                 162.5
# 294              59.53                4.9                163.58
# ...

# %%
evap1.drop([0,1],inplace = True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_8228\4071555344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   evap1.drop([0,1],inplace = True)

# %%
evap1.head()
# Out:
#                  Time FIC3001A.PV | Value FIC3011A.PV | Value  \
# 293  04-04-2022 00:45               21.25               -0.07
# 294  04-04-2022 01:00               18.27               -0.07
# 295  04-04-2022 01:15               12.47               -0.07
# 296  04-04-2022 01:30                0.02               -0.04
# 297  04-04-2022 01:45               -0.01               -0.05
#
#     PIC3031A.PV | Value PIC3001A.PV | Value TI3001A.PV | Value  \
# 293                0.05              -82.17               52.8
# 294                0.05              -80.22              55.93
# 295                0.05             -104.02              54.39
# 296                0.05              -88.24              55.31
# 297                0.05              -81.89              54.81
#
#     TI3011A.PV | Value FI3021A.PV | Value GA3001A-AI.PV | Value
# 293              59.11               5.02                 162.5
# 294              59.53                4.9                163.58
# ...

# %%
evap1.sort_values(by = ['Time'],ascending= True)
# Out:
#                    Time FIC3001A.PV | Value FIC3011A.PV | Value  \
# 3074   01-05-2022 00:00                9.59                5.87
# 3075   01-05-2022 00:15                9.09                5.87
# 3076   01-05-2022 00:30                8.55                6.13
# 3077   01-05-2022 00:45               10.16                6.02
# 3078   01-05-2022 01:00                9.02                6.01
# ...                 ...                 ...                 ...
# 20733  31-10-2022 22:45                7.79                5.71
# 20734  31-10-2022 23:00                4.57                5.41
# 20735  31-10-2022 23:15                1.35                5.18
# 20736  31-10-2022 23:30                8.03                4.92
# 20737  31-10-2022 23:45                8.15                4.56
#
#       PIC3031A.PV | Value PIC3001A.PV | Value TI3001A.PV | Value  \
# 3074                 0.85             -555.24              77.52
# ...

# %%
evap1.to_csv("evap_clean.csv")

# %%
print(evap1['Time'].iloc[0])
# Out:
# 04-04-2022 00:45
