# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
sp = pd.read_csv(r'C:\Users\Dell\Downloads\SpSteam-2021.csv')

# %%
sp
# Out:
#                 Trend  Sulphur temp  Air Temp  Air Pressure  Burner temp  \
# 0    01-02-2022 01:00        129.03    115.55        533.45      1107.17
# 1    01-02-2022 02:00        128.77    116.81        532.47      1107.51
# 2    01-02-2022 03:00        128.57    114.05        534.48      1103.31
# 3    01-02-2022 04:00        128.49    113.44        534.67      1102.78
# 4    01-02-2022 05:00        128.38    113.42        536.33      1102.98
# ..                ...           ...       ...           ...          ...
# 883               NaN           NaN       NaN           NaN          NaN
# 884               NaN           NaN       NaN           NaN          NaN
# 885               NaN           NaN       NaN           NaN          NaN
# 886               NaN           NaN       NaN           NaN          NaN
# 887               NaN           NaN       NaN           NaN          NaN
#
#      pressure drop in Furnace+WHB  WHB Outlet Temp  BFW Temp  \
# ...

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 888 entries, 0 to 887
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Trend                         671 non-null    object
#  1   Sulphur temp                  659 non-null    float64
#  2   Air Temp                      659 non-null    float64
#  3   Air Pressure                  659 non-null    float64
#  4   Burner temp                   659 non-null    float64
#  5   pressure drop in Furnace+WHB  659 non-null    float64
#  6   WHB Outlet Temp               659 non-null    float64
#  7   BFW Temp                      659 non-null    float64
#  8   Boiler out Steam temp         661 non-null    float64
#  9   Boiler out steam pressure     659 non-null    float64
#  10  Flowmter reading              671 non-null    float64
#  11  Production Rate               671 non-null    float64
# ...

# %%
sp.isnull()
# Out:
#      Trend  Sulphur temp  Air Temp  Air Pressure  Burner temp  \
# 0    False         False     False         False        False
# 1    False         False     False         False        False
# 2    False         False     False         False        False
# 3    False         False     False         False        False
# 4    False         False     False         False        False
# ..     ...           ...       ...           ...          ...
# 883   True          True      True          True         True
# 884   True          True      True          True         True
# 885   True          True      True          True         True
# 886   True          True      True          True         True
# 887   True          True      True          True         True
#
#      pressure drop in Furnace+WHB  WHB Outlet Temp  BFW Temp  \
# 0                           False            False     False
# 1                           False            False     False
# ...

# %%
sp.dropna()
# Out:
#                 Trend  Sulphur temp  Air Temp  Air Pressure  Burner temp  \
# 0    01-02-2022 01:00        129.03    115.55        533.45      1107.17
# 1    01-02-2022 02:00        128.77    116.81        532.47      1107.51
# 2    01-02-2022 03:00        128.57    114.05        534.48      1103.31
# 3    01-02-2022 04:00        128.49    113.44        534.67      1102.78
# 4    01-02-2022 05:00        128.38    113.42        536.33      1102.98
# ..                ...           ...       ...           ...          ...
# 666  28-02-2022 20:00        117.90    115.52        543.87      1043.45
# 667  28-02-2022 21:00        108.72    116.37        546.86      1039.47
# 668  28-02-2022 22:00        108.22    112.62        515.54      1039.80
# 669  28-02-2022 23:00        107.92    108.06        493.62      1041.08
# 670  01-03-2022 00:00        107.14    107.77        493.48      1041.51
#
#      pressure drop in Furnace+WHB  WHB Outlet Temp  BFW Temp  \
# ...

# %%
req_df = sp[sp['Air Pressure']>500]

# %%
req_df
# Out:
#                 Trend  Sulphur temp  Air Temp  Air Pressure  Burner temp  \
# 0    01-02-2022 01:00        129.03    115.55        533.45      1107.17
# 1    01-02-2022 02:00        128.77    116.81        532.47      1107.51
# 2    01-02-2022 03:00        128.57    114.05        534.48      1103.31
# 3    01-02-2022 04:00        128.49    113.44        534.67      1102.78
# 4    01-02-2022 05:00        128.38    113.42        536.33      1102.98
# ..                ...           ...       ...           ...          ...
# 664  28-02-2022 18:00        122.85    116.31        546.60      1044.52
# 665  28-02-2022 19:00        124.49    115.58        544.16      1046.42
# 666  28-02-2022 20:00        117.90    115.52        543.87      1043.45
# 667  28-02-2022 21:00        108.72    116.37        546.86      1039.47
# 668  28-02-2022 22:00        108.22    112.62        515.54      1039.80
#
#      pressure drop in Furnace+WHB  WHB Outlet Temp  BFW Temp  \
# ...

# %%
req_df1 =  req_df[req_df['Burner temp']>1050]

# %%
req_df2 = req_df1[req_df1['Production Rate']>50]

# %%
req_df2
# Out:
#                 Trend  Sulphur temp  Air Temp  Air Pressure  Burner temp  \
# 2    01-01-2022 03:00        128.65    109.95        538.28      1095.56
# 3    01-01-2022 04:00        128.85    109.49        538.04      1096.15
# 4    01-01-2022 05:00        128.76    109.87        541.98      1094.37
# 5    01-01-2022 06:00        128.71    110.28        542.90      1094.23
# 6    01-01-2022 07:00        128.53    110.10        545.04      1093.08
# ..                ...           ...       ...           ...          ...
# 732  31-01-2022 18:00        128.38    117.05        539.53      1105.68
# 733  31-01-2022 19:00        128.36    117.00        536.88      1106.48
# 734  31-01-2022 20:00        127.93    116.49        533.80      1106.73
# 735  31-01-2022 21:00        127.60    116.22        533.32      1106.80
# 737  31-01-2022 23:00        128.45    116.29        537.47      1103.01
#
#      pressure drop in Furnace+WHB  WHB Outlet Temp  BFW Temp  \
# ...

# %%
req_df2.to_csv("final_sp.csv")
